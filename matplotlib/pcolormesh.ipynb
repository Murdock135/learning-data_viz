# %% [markdown]
# References
#
# 1. https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.pcolormesh.html
# 2. https://www.youtube.com/watch?v=aLckWub7kZM

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
X = np.array([[0, 1, 2],
              [0, 1, 2],
              [0, 1, 2]])
Y = np.array([[0,0,0],
              [1,1,1],
              [2,2,2]])
Z = np.array([[0,0.5,1],
              [1,1.5,2],
              [2,2.5,3]])

# %%
fig, ax = plt.subplots()
ax.imshow(Z)
